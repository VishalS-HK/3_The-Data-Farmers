# %% [markdown]
# # Libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing Keras and Tensorflow libraries

# %%
import keras 

from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array, load_img

from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions

# %%
train_data_gen = ImageDataGenerator(zoom_range = 0.6, shear_range = 0.3, horizontal_flip = True, preprocessing_function = preprocess_input)

validation_data_gen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
training_set = train_data_gen.flow_from_directory(directory = "datasets/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train", target_size = (256, 256), batch_size = 32)

validation_set = validation_data_gen.flow_from_directory(directory = "datasets/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train", target_size = (256, 256,), batch_size = 32)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 70295 images belonging to 38 classes.

# %% [markdown]
# t_img, label = training_set.next()

# %%
def plotImage(img_arr,label):

    for im, l in zip(img_arr,label):
        plt.figure(figsize=(5,5))
        plt.imshow(im)
        plt.show()

# %%
plotImage(t_img[:3],label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Building the model

# %%
from keras.layers import Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
import keras

# %%
base_model = VGG16(input_shape(256,256,3), include_top = false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 base_model = VGG16(input_shape(256,256,3), include_top = false)
#
# NameError: name 'input_shape' is not defined
